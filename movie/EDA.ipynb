# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
m = pd.read_csv('src/KOBIS_개봉일람.csv', encoding='cp949')

m
# Out:
#           순번         영화명           감독                           제작사
# 0          1          명량          김한민                     (주)빅스톤픽쳐스  \
# 1          2        극한직업          이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2          3   신과함께-죄와 벌          김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3          4        국제시장          윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4          5  어벤져스: 엔드게임   안소니 루소조 루소                           NaN
# ...      ...         ...          ...                           ...
# 27399  27400    V2 폭파대작전  엔조 G. 카스텔라리                           NaN
# 27400  27401       W의 비극          김수형                      한진흥업주식회사
# 27401  27402         X게임    엠마뉴엘 그리센티                           NaN
# 27402  27403       Y의 체험          이장호                       판영화사(주)
# 27403  27404     YMCA야구단          김현석                  (주)명필름CJ ENM
#
#                       수입사                 배급사         개봉일  영화유형 영화형태    국적
# ...

# %%
m = m.drop(['순번'], axis=1)

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27404 entries, 0 to 27403
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영화명      27404 non-null  object
#  1   감독       25745 non-null  object
#  2   제작사      11666 non-null  object
#  3   수입사      15888 non-null  object
#  4   배급사      20757 non-null  object
#  5   개봉일      27382 non-null  object
#  6   영화유형     27404 non-null  object
#  7   영화형태     27387 non-null  object
#  8   국적       27393 non-null  object
#  9   전국 스크린수  27404 non-null  int64
#  10  전국 매출액   26348 non-null  float64
#  11  전국 관객수   27404 non-null  int64
#  12  서울 매출액   26342 non-null  float64
#  13  서울 관객수   27404 non-null  int64
#  14  장르       27213 non-null  object
#  15  등급       26916 non-null  object
#  16  영화구분     27404 non-null  object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 3.6+ MB

# %%
m.isna().sum()
# Out:
# 영화명            0
# 감독          1659
# 제작사        15738
# 수입사        11516
# 배급사         6647
# 개봉일           22
# 영화유형           0
# 영화형태          17
# 국적            11
# 전국 스크린수        0
# 전국 매출액      1056
# 전국 관객수         0
# 서울 매출액      1062
# 서울 관객수         0
# 장르           191
# 등급           488
# 영화구분           0
# dtype: int64

# %%
m = m[m['전국 스크린수'] > m['전국 스크린수'].mean()]

m
# Out:
#                      영화명          감독                           제작사
# 0                     명량         김한민                     (주)빅스톤픽쳐스  \
# 1                   극한직업         이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2              신과함께-죄와 벌         김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3                   국제시장         윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4             어벤져스: 엔드게임  안소니 루소조 루소                           NaN
# ...                  ...         ...                           ...
# 8041           늑대와 빨간 재킷      뱅상 파로노                           NaN
# 8157      마라가 큰 결정을 해야 해     로버트 루케틱                           NaN
# 8165            락다운 213주      아담 메이슨                           NaN
# 8263      래미의 드래곤월드 구출작전       웨이밍 황                           NaN
# 9101  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키                           NaN
#
#                      수입사                 배급사         개봉일  영화유형 영화형태   국적
# 0                    NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편   한국  \
# ...

# %%
m.isna().sum()
# Out:
# 영화명           0
# 감독           99
# 제작사        2541
# 수입사        1272
# 배급사           7
# 개봉일           0
# 영화유형          0
# 영화형태          0
# 국적            0
# 전국 스크린수       0
# 전국 매출액        0
# 전국 관객수        0
# 서울 매출액        0
# 서울 관객수        0
# 장르            0
# 등급            0
# 영화구분          0
# dtype: int64

# %%
m.loc[m['감독'].isna()]
# Out:
#                            영화명   감독                            제작사
# 1608              러브 유어셀프 인 서울  NaN  빅히트 엔터테인먼트씨제이 씨지브이(CJ CGV)(주)  \
# 1966                 프리즌 이스케이프  NaN                            NaN
# 2473                    로스트 시티  NaN                            NaN
# 2567  그대 고맙소 : 김호중 생애 첫 팬미팅 무비  NaN                  씨제이포디플렉스 주식회사
# 2732         던전 앤 드래곤: 도적들의 명예  NaN                            NaN
# ...                        ...  ...                            ...
# 7594                      코드 8  NaN                            NaN
# 7665                  섀도우 클라우드  NaN                            NaN
# 7679                       엠티맨  NaN                            NaN
# 7822                    퍼펙트 스틸  NaN                            NaN
# 7967                       체이싱  NaN                            NaN
#
#                      수입사                  배급사         개봉일  영화유형 영화형태   국적
# 1608                 NaN  씨제이 씨지브이(CJ CGV)(주)  2019-01-26  개봉영화   장편   한국  \
# ...

# %%
m.loc[m['제작사'].isna()]
# Out:
#                      영화명          감독  제작사                 수입사
# 4             어벤져스: 엔드게임  안소니 루소조 루소  NaN  월트디즈니컴퍼니코리아 유한책임회사  \
# 5                 겨울왕국 2  크리스 벅제니퍼 리  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 13                   알라딘       가이 리치  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 22          어벤져스: 인피니티 워  안소니 루소조 루소  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 24             아바타: 물의 길     제임스 카메론  NaN  월트디즈니컴퍼니코리아 유한책임회사
# ...                  ...         ...  ...                 ...
# 8041           늑대와 빨간 재킷      뱅상 파로노  NaN             판씨네마(주)
# 8157      마라가 큰 결정을 해야 해     로버트 루케틱  NaN            (주)영화사오원
# 8165            락다운 213주      아담 메이슨  NaN          그린나래미디어(주)
# 8263      래미의 드래곤월드 구출작전       웨이밍 황  NaN          와이드 릴리즈(주)
# 9101  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키  NaN         (주)박수엔터테인먼트
#
#                      배급사         개봉일  영화유형 영화형태   국적  전국 스크린수        전국 매출액
# 4     월트디즈니컴퍼니코리아 유한책임회사  2019-04-24  개봉영화   장편   미국     2835  1.221827e+11  \
# ...

# %%
m.loc[(m['수입사'].isna()) & (m['국적'] != '한국')]
# Out:
#                         영화명                   감독
# 840               삼국지:용의 부활                  이인항  \
# 1139       명탐정 코난 : 침묵의 15분               시즈노 코분
# 1251            나쁜 녀석들: 포에버        아딜 엘 아르비빌랄 팔라
# 1284               러브 & 드럭스              에드워드 즈윅
# 1423             작은 영웅 데스페로        샘 펠로버트 스티븐헤이겐
# 1658                     옥자                  봉준호
# 2182                  스플라이스              빈센조 나탈리
# 2262                     화피                  진가상
# 2303                 꽃보다 남자             이시이 야스하루
# 2663              샤크 나이트 3D          데이비드 R. 엘리스
# 2727                 옥보단 3D                  손립기
# 2728            나의 청춘은 너의 것                주동대몽영
# 2813             맨 인 더 다크 2             로도 사야구에즈
# 2847                  돈 룩 업               아담 맥케이
# 2873   돈비 어프레이드 : 어둠 속의 속삭임               트로이 닉시
# 2933                   천녀유혼                  엽위신
# 2992            퍼피 구조대 더 무비               캘런 브런커
# 3018  극장판 아따맘마3D : 엄마는 초능력자             타카하시 와타루
# ...

# %%
m.loc[m['배급사'].isna()]
# Out:
#               영화명       감독           제작사                  수입사  배급사
# 629          더 게임      윤인호  (주)프라임엔터테인먼트                  NaN  NaN  \
# 1387      퍼블릭 에너미    마이클 만      유니버셜 픽쳐스  유니버설픽쳐스인터내셔널 코리아(유)  NaN
# 1947  코렐라인: 비밀의 문    헨리 셀릭           NaN  유니버설픽쳐스인터내셔널 코리아(유)  NaN
# 2243  스테이트 오브 플레이  케빈 맥도널드           NaN  유니버설픽쳐스인터내셔널 코리아(유)  NaN
# 2753           출국      노규엽   주식회사 디에스이이디                  NaN  NaN
# 3234        작은 연못      이상우     유한회사 제이필름                  NaN  NaN
# 3779     컴 아웃 파이팅   디토 몬티엘        로그 픽쳐스  유니버설픽쳐스인터내셔널 코리아(유)  NaN
#
#              개봉일  영화유형 영화형태  국적  전국 스크린수        전국 매출액   전국 관객수        서울 매출액
# 629   2008-01-30  개봉영화   장편  한국      339  9.869347e+09  1496214  3.151456e+09  \
# 1387  2009-08-12  개봉영화   장편  미국      292  3.424720e+09   464076  1.465109e+09
# 1947  2009-05-21  개봉영화   장편  미국      251  1.448857e+09   222594  4.169970e+08
# 2243  2009-04-30  개봉영화   장편  미국      197  9.985678e+08   150447  4.113845e+08
# ...

# %%
for i, j in enumerate(m.개봉일):
    if len(j.split('-')) != 3:
        print(i)

# %%
m.영화유형.unique()
# Out:
# array(['개봉영화'], dtype=object)

# %%
m.영화형태.unique()
# Out:
# array(['장편', '옴니버스', '단편'], dtype=object)

# %%
m.국적.unique()
# Out:
# array(['한국', '미국', '일본', '영국', '중국', '프랑스', '벨기에', '독일', '인도', '아이슬란드',
#        '캐나다', '스페인', '러시아', '아일랜드', '남아프리카공화국', '대만', '핀란드', '홍콩', '스웨덴',
#        '이탈리아', '호주', '덴마크', '기타', '아르헨티나', '헝가리', '태국', '페루', '멕시코',
#        '우크라이나', '노르웨이', '터키', '뉴질랜드', '체코', '그리스', '폴란드', '칠레', '말레이시아',
#        '인도네시아', '브라질', '네덜란드', '이스라엘', '에스토니아'], dtype=object)

# %%
nation = '|'.join(m['국적'].value_counts().head(10).index)

nation
# Out:
# '미국|한국|일본|영국|프랑스|중국|독일|스페인|러시아|홍콩'

# %%
print(len(m.loc[~m['국적'].str.contains(nation)]))

m.loc[~m['국적'].str.contains(nation), '국적'] = '기타'

print(len(m[m['국적'] == '기타']))
print(m.국적.unique())
# Out:
# 264
# 264
# ['한국' '미국' '일본' '영국' '중국' '프랑스' '기타' '독일' '스페인' '러시아' '홍콩']

# %%
m.장르.unique()
# Out:
# array(['사극', '코미디', '판타지', '드라마', '액션', '애니메이션', 'SF', '범죄', '어드벤처', '전쟁',
#        '미스터리', '서부극(웨스턴)', '멜로/로맨스', '스릴러', '다큐멘터리', '공포(호러)', '뮤지컬',
#        '가족', '기타', '공연', '성인물(에로)'], dtype=object)

# %%
m.등급.unique()
# 전체 관람가, 12세 이상 관람가, 15세 이상 관람가, 청소년 관람 불가, 제한 상영가
# Out:
# array(['15세이상관람가', '12세이상관람가', '전체관람가', '청소년관람불가', '청소년관람불가15세이상관람가',
#        '12세관람가', '15세관람가', '12세이상관람가15세이상관람가'], dtype=object)

# %%
m[m['등급'] == '청소년관람불가15세이상관람가']
# 그랜드 부다페스트 호텔 15세
# 그녀 15세
# Out:
#                영화명       감독  제작사                    수입사
# 1025  그랜드 부다페스트 호텔   웨스 앤더슨  NaN  (주)피터팬픽쳐스이십세기폭스코리아(주)  \
# 1589            그녀  스파이크 존즈  NaN                주식회사 더쿱
#
#                              배급사         개봉일  영화유형 영화형태  국적  전국 스크린수
# 1025       (주)피터팬픽쳐스이십세기폭스코리아(주)  2014-03-20  개봉영화   장편  미국      163  \
# 1589  주식회사 더쿱유니버설픽쳐스인터내셔널 코리아(유)  2014-05-22  개봉영화   장편  미국      168
#
#             전국 매출액  전국 관객수        서울 매출액  서울 관객수    장르               등급
# 1025  6.012396e+09  773649  3.516636e+09  444985  미스터리  청소년관람불가15세이상관람가  \
# 1589  2.861230e+09  351091  1.876009e+09  227358   드라마  청소년관람불가15세이상관람가
#
#          영화구분
# 1025  독립/예술영화
# 1589  독립/예술영화

# %%
m.loc[m['등급'] == '청소년관람불가15세이상관람가', '등급'] = '15세이상관람가'

m[m['등급'] == '청소년관람불가15세이상관람가']
# Out:
# Empty DataFrame
# Columns: [영화명, 감독, 제작사, 수입사, 배급사, 개봉일, 영화유형, 영화형태, 국적, 전국 스크린수, 전국 매출액, 전국 관객수, 서울 매출액, 서울 관객수, 장르, 등급, 영화구분]
# Index: []

# %%
m[m['등급'] == '12세관람가']
# 던전 앤 드래곤: 도적들의 명예 12세
# Out:
#                     영화명   감독  제작사                수입사                배급사
# 2732  던전 앤 드래곤: 도적들의 명예  NaN  NaN  롯데컬처웍스(주)롯데엔터테인먼트  롯데컬처웍스(주)롯데엔터테인먼트  \
#
#              개봉일  영화유형 영화형태  국적  전국 스크린수       전국 매출액  전국 관객수       서울 매출액
# 2732  2023-03-29  개봉영화   장편  미국     1105  794264727.0   83761  278163526.0  \
#
#       서울 관객수  장르      등급  영화구분
# 2732   27446  액션  12세관람가  일반영화

# %%
m.loc[m['등급'] == '12세관람가', '등급'] = '12세 이상 관람가'

m[m['등급'] == '12세관람가']
# Out:
# Empty DataFrame
# Columns: [영화명, 감독, 제작사, 수입사, 배급사, 개봉일, 영화유형, 영화형태, 국적, 전국 스크린수, 전국 매출액, 전국 관객수, 서울 매출액, 서울 관객수, 장르, 등급, 영화구분]
# Index: []

# %%
m[m['등급'] == '15세관람가']
# 피아니스트의 전설 15세
# Out:
#             영화명         감독  제작사   수입사        배급사         개봉일  영화유형 영화형태  국적
# 3349  피아니스트의 전설  쥬세페 토르나토레  NaN  일미디어  (주)라이크콘텐츠  2020-01-01  개봉영화   장편  기타  \
#
#       전국 스크린수       전국 매출액  전국 관객수       서울 매출액  서울 관객수   장르      등급     영화구분
# 3349       69  340627562.0   41680  207078442.0   24197  드라마  15세관람가  독립/예술영화

# %%
m.loc[m['등급'] == '15세관람가', '등급'] = '15세이상관람가'

m[m['등급'] == '15세관람가']
# Out:
# Empty DataFrame
# Columns: [영화명, 감독, 제작사, 수입사, 배급사, 개봉일, 영화유형, 영화형태, 국적, 전국 스크린수, 전국 매출액, 전국 관객수, 서울 매출액, 서울 관객수, 장르, 등급, 영화구분]
# Index: []

# %%
m[m['등급'] == '12세이상관람가15세이상관람가']
# 라이크 크레이지 12세
# Out:
#            영화명         감독  제작사         수입사         배급사         개봉일  영화유형 영화형태
# 4773  라이크 크레이지  드레이크 도레무스  NaN  (주)팝엔터테인먼트  (주)팝엔터테인먼트  2018-05-30  개봉영화   장편  \
#
#       국적  전국 스크린수      전국 매출액  전국 관객수      서울 매출액  서울 관객수   장르
# 4773  미국      116  81549980.0   10850  39981980.0    5165  드라마  \
#
#                     등급     영화구분
# 4773  12세이상관람가15세이상관람가  독립/예술영화

# %%
m.loc[m['등급'] == '12세이상관람가15세이상관람가', '등급'] = '12세이상관람가'

m[m['등급'] == '12세이상관람가15세이상관람가']
# Out:
# Empty DataFrame
# Columns: [영화명, 감독, 제작사, 수입사, 배급사, 개봉일, 영화유형, 영화형태, 국적, 전국 스크린수, 전국 매출액, 전국 관객수, 서울 매출액, 서울 관객수, 장르, 등급, 영화구분]
# Index: []

# %%
m.영화구분.unique()
# Out:
# array(['일반영화', '독립/예술영화'], dtype=object)

# %%
m.isna().sum()
# Out:
# 영화명           0
# 감독           99
# 제작사        2541
# 수입사        1272
# 배급사           7
# 개봉일           0
# 영화유형          0
# 영화형태          0
# 국적            0
# 전국 스크린수       0
# 전국 매출액        0
# 전국 관객수        0
# 서울 매출액        0
# 서울 관객수        0
# 장르            0
# 등급            0
# 영화구분          0
# dtype: int64

# %%
m1 = m[['전국 관객수']].groupby(m['감독']).sum()
m1.loc[m1['전국 관객수'] == 0, '전국 관객수'] = 1
m1 = m1.apply(np.log).reset_index()
m1.rename(columns={'전국 관객수':'감독_로그'}, inplace=True)
m1
# Out:
#               감독      감독_로그
# 0       D.J. 카루소  15.037578
# 1      F. 게리 그레이  15.494588
# 2        J 블레이크슨  12.002799
# 3         J.C 챈더   9.061144
# 4     J.J. 에이브럼스  15.757183
# ...          ...        ...
# 2436    히라오 타카유키  10.045725
# 2437   히라카와 유이치로   8.935640
# 2438     히로키 류이치  12.164625
# 2439    히시다 마사카즈  11.926630
# 2440    히즈엠티 선교회  10.875251
#
# [2441 rows x 2 columns]

# %%
m
# Out:
#                      영화명          감독                           제작사
# 0                     명량         김한민                     (주)빅스톤픽쳐스  \
# 1                   극한직업         이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2              신과함께-죄와 벌         김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3                   국제시장         윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4             어벤져스: 엔드게임  안소니 루소조 루소                           NaN
# ...                  ...         ...                           ...
# 8041           늑대와 빨간 재킷      뱅상 파로노                           NaN
# 8157      마라가 큰 결정을 해야 해     로버트 루케틱                           NaN
# 8165            락다운 213주      아담 메이슨                           NaN
# 8263      래미의 드래곤월드 구출작전       웨이밍 황                           NaN
# 9101  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키                           NaN
#
#                      수입사                 배급사         개봉일  영화유형 영화형태   국적
# 0                    NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편   한국  \
# ...

# %%
m = pd.merge(m, m1, how='left', left_on='감독', right_on='감독')
m
# Out:
#                      영화명          감독                           제작사
# 0                     명량         김한민                     (주)빅스톤픽쳐스  \
# 1                   극한직업         이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2              신과함께-죄와 벌         김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3                   국제시장         윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4             어벤져스: 엔드게임  안소니 루소조 루소                           NaN
# ...                  ...         ...                           ...
# 3970           늑대와 빨간 재킷      뱅상 파로노                           NaN
# 3971      마라가 큰 결정을 해야 해     로버트 루케틱                           NaN
# 3972            락다운 213주      아담 메이슨                           NaN
# 3973      래미의 드래곤월드 구출작전       웨이밍 황                           NaN
# 3974  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키                           NaN
#
#                      수입사                 배급사         개봉일  영화유형 영화형태   국적
# 0                    NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편   한국  \
# ...

# %%
m1 = m[['전국 관객수']].groupby(m['제작사']).sum()
m1.loc[m1['전국 관객수'] == 0, '전국 관객수'] = 1
m1 = m1.apply(np.log).reset_index()
m1.rename(columns={'전국 관객수':'제작사_로그'}, inplace=True)
m1
# Out:
#                            제작사     제작사_로그
# 0       (Europe) Media Program  11.115458
# 1               (유)내부자들 문화전문회사  16.029894
# 2                  (유)박열문화전문회사  14.673822
# 3           (유)이층의 악당 문화산업전문회사  13.313354
# 4                       (재)CBS  11.126351
# ..                         ...        ...
# 993  휠므빠말주식회사이십세기폭스 인터내셔널 프로덕션  11.802254
# 994     휴메니테라픽쳐스(주)컴퍼니에이이엔티(주)  10.382141
# 995                 히어로 엔터테인먼트  10.850404
# 996         히트 엔터테인먼트니트로겐 스튜디오   9.691902
# 997        힘컨텐츠(주)한국교육방송공사 EBS  11.605268
#
# [998 rows x 2 columns]

# %%
m = pd.merge(m, m1, how='left', left_on='제작사', right_on='제작사')
m
# Out:
#                      영화명          감독                           제작사
# 0                     명량         김한민                     (주)빅스톤픽쳐스  \
# 1                   극한직업         이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2              신과함께-죄와 벌         김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3                   국제시장         윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4             어벤져스: 엔드게임  안소니 루소조 루소                           NaN
# ...                  ...         ...                           ...
# 3970           늑대와 빨간 재킷      뱅상 파로노                           NaN
# 3971      마라가 큰 결정을 해야 해     로버트 루케틱                           NaN
# 3972            락다운 213주      아담 메이슨                           NaN
# 3973      래미의 드래곤월드 구출작전       웨이밍 황                           NaN
# 3974  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키                           NaN
#
#                      수입사                 배급사         개봉일  영화유형 영화형태   국적
# 0                    NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편   한국  \
# ...

# %%
m1 = m[['전국 스크린수']].groupby(m['배급사']).sum()
m1.loc[m1['전국 스크린수'] == 0, '전국 스크린수'] = 1
m1 = m1.apply(np.log).reset_index()
m1.rename(columns={'전국 스크린수':'배급사_로그'}, inplace=True)
m1
# Out:
#                          배급사    배급사_로그
# 0              (유)씨에이치엔터테인먼트  5.752573
# 1    (유)영화사 화수분(주)에스비에스콘텐츠허브  5.488938
# 2                  (유)조이앤시네마  6.381816
# 3      (유)조이앤시네마(주)제이앤씨미디어그룹  4.369448
# 4                     (재)CBS  6.359574
# ..                       ...       ...
# 510                  필라멘트픽쳐스  8.049746
# 511                     필름다빈  5.463832
# 512      한국소니픽쳐스릴리징브에나비스타영화㈜  9.993054
# 513                     홀리가든  4.189655
# 514          힘컨텐츠(주)(주)디스테이션  5.252273
#
# [515 rows x 2 columns]

# %%
m = pd.merge(m, m1, how='left', left_on='배급사', right_on='배급사')
m
# Out:
#                      영화명          감독                           제작사
# 0                     명량         김한민                     (주)빅스톤픽쳐스  \
# 1                   극한직업         이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2              신과함께-죄와 벌         김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3                   국제시장         윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4             어벤져스: 엔드게임  안소니 루소조 루소                           NaN
# ...                  ...         ...                           ...
# 3970           늑대와 빨간 재킷      뱅상 파로노                           NaN
# 3971      마라가 큰 결정을 해야 해     로버트 루케틱                           NaN
# 3972            락다운 213주      아담 메이슨                           NaN
# 3973      래미의 드래곤월드 구출작전       웨이밍 황                           NaN
# 3974  블루 서멀 같은 하늘을 보고 싶어    타치바나 마사키                           NaN
#
#                      수입사                 배급사         개봉일  영화유형 영화형태   국적
# 0                    NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편   한국  \
# ...

# %%
c = m[['전국 스크린수', '전국 매출액', '전국 관객수', '서울 매출액', '서울 관객수', '감독_로그', '제작사_로그', '배급사_로그']]

c.corr()
# Out:
#           전국 스크린수    전국 매출액    전국 관객수    서울 매출액    서울 관객수     감독_로그    제작사_로그
# 전국 스크린수  1.000000  0.689977  0.660026  0.667923  0.636888  0.604440  0.584731  \
# 전국 매출액   0.689977  1.000000  0.991560  0.986449  0.975193  0.517147  0.527415
# 전국 관객수   0.660026  0.991560  1.000000  0.981189  0.986967  0.527521  0.533437
# 서울 매출액   0.667923  0.986449  0.981189  1.000000  0.991000  0.529029  0.535639
# 서울 관객수   0.636888  0.975193  0.986967  0.991000  1.000000  0.538439  0.538755
# 감독_로그    0.604440  0.517147  0.527521  0.529029  0.538439  1.000000  0.735385
# 제작사_로그   0.584731  0.527415  0.533437  0.535639  0.538755  0.735385  1.000000
# 배급사_로그   0.391885  0.258097  0.264109  0.252290  0.257670  0.412423  0.488293
#
#            배급사_로그
# 전국 스크린수  0.391885
# 전국 매출액   0.258097
# 전국 관객수   0.264109
# 서울 매출액   0.252290
# 서울 관객수   0.257670
# 감독_로그    0.412423
# 제작사_로그   0.488293
# 배급사_로그   1.000000

# %%
fig = px.imshow(c, text_auto=True)
fig.show()
