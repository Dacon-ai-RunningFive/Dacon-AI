# %%
import pandas as pd
import plotly.express as px

# %%
m = pd.read_csv('src/KOBIS_개봉일람.csv', encoding='cp949')

m
# Out:
#           순번         영화명           감독                           제작사
# 0          1          명량          김한민                     (주)빅스톤픽쳐스  \
# 1          2        극한직업          이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2          3   신과함께-죄와 벌          김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3          4        국제시장          윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4          5  어벤져스: 엔드게임   안소니 루소조 루소                           NaN
# ...      ...         ...          ...                           ...
# 27399  27400    V2 폭파대작전  엔조 G. 카스텔라리                           NaN
# 27400  27401       W의 비극          김수형                      한진흥업주식회사
# 27401  27402         X게임    엠마뉴엘 그리센티                           NaN
# 27402  27403       Y의 체험          이장호                       판영화사(주)
# 27403  27404     YMCA야구단          김현석                  (주)명필름CJ ENM
#
#                       수입사                 배급사         개봉일  영화유형 영화형태    국적
# ...

# %%
m = m.drop(['순번'], axis=1)

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27404 entries, 0 to 27403
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영화명      27404 non-null  object
#  1   감독       25745 non-null  object
#  2   제작사      11666 non-null  object
#  3   수입사      15888 non-null  object
#  4   배급사      20757 non-null  object
#  5   개봉일      27382 non-null  object
#  6   영화유형     27404 non-null  object
#  7   영화형태     27387 non-null  object
#  8   국적       27393 non-null  object
#  9   전국 스크린수  27404 non-null  int64
#  10  전국 매출액   26348 non-null  float64
#  11  전국 관객수   27404 non-null  int64
#  12  서울 매출액   26342 non-null  float64
#  13  서울 관객수   27404 non-null  int64
#  14  장르       27213 non-null  object
#  15  등급       26916 non-null  object
#  16  영화구분     27404 non-null  object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 3.6+ MB

# %%
m.isna().sum()
# Out:
# 영화명            0
# 감독          1659
# 제작사        15738
# 수입사        11516
# 배급사         6647
# 개봉일           22
# 영화유형           0
# 영화형태          17
# 국적            11
# 전국 스크린수        0
# 전국 매출액      1056
# 전국 관객수         0
# 서울 매출액      1062
# 서울 관객수         0
# 장르           191
# 등급           488
# 영화구분           0
# dtype: int64

# %%
m.loc[m['감독'].isna()]
# Out:
#                             영화명   감독                            제작사
# 246                     오! 브라더스  NaN                            NaN  \
# 1608               러브 유어셀프 인 서울  NaN  빅히트 엔터테인먼트씨제이 씨지브이(CJ CGV)(주)
# 1966                  프리즌 이스케이프  NaN                            NaN
# 2473                     로스트 시티  NaN                            NaN
# 2567   그대 고맙소 : 김호중 생애 첫 팬미팅 무비  NaN                  씨제이포디플렉스 주식회사
# ...                         ...  ...                            ...
# 27323               500만 달러의 모험  NaN                            NaN
# 27343                   8번가의 기적  NaN              엠블린엔터테인먼트유니버셜 픽쳐스
# 27354                   9일간의 정사  NaN                            NaN
# 27396                   SAS 특공대  NaN                   랭크 필름 오가니제이션
# 27398          UFO를 타고 온 외계인 왕자  NaN                            NaN
#
#                         수입사                  배급사         개봉일  영화유형 영화형태    국적
# ...

# %%
m.loc[m['제작사'].isna()]
# Out:
#                     영화명           감독  제작사                 수입사
# 4            어벤져스: 엔드게임   안소니 루소조 루소  NaN  월트디즈니컴퍼니코리아 유한책임회사  \
# 5                겨울왕국 2   크리스 벅제니퍼 리  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 13                  알라딘        가이 리치  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 22         어벤져스: 인피니티 워   안소니 루소조 루소  NaN  월트디즈니컴퍼니코리아 유한책임회사
# 24            아바타: 물의 길      제임스 카메론  NaN  월트디즈니컴퍼니코리아 유한책임회사
# ...                 ...          ...  ...                 ...
# 27394            O양의 함정          낙가사  NaN             (주)대성영화
# 27395         SAS미망인의 눈  앤드류 V. 맥라글렌  NaN             (주)우진필림
# 27398  UFO를 타고 온 외계인 왕자          NaN  NaN                 NaN
# 27399          V2 폭파대작전  엔조 G. 카스텔라리  NaN           (주)동아수출공사
# 27401               X게임    엠마뉴엘 그리센티  NaN             (주)한영필림
#
#                       배급사         개봉일  영화유형 영화형태    국적  전국 스크린수        전국 매출액
# 4      월트디즈니컴퍼니코리아 유한책임회사  2019-04-24  개봉영화   장편    미국     2835  1.221827e+11  \
# ...

# %%
m.loc[m['수입사'].isna()]
# Out:
#                     영화명   감독                           제작사  수입사
# 0                    명량  김한민                     (주)빅스톤픽쳐스  NaN  \
# 1                  극한직업  이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠  NaN
# 2             신과함께-죄와 벌  김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오  NaN
# 3                  국제시장  윤제균            (주)제이케이필름(주)씨제이이엔엠  NaN
# 7                   베테랑  류승완                (주)외유내강(주)필름케이  NaN
# ...                 ...  ...                           ...  ...
# 27396           SAS 특공대  NaN                  랭크 필름 오가니제이션  NaN
# 27398  UFO를 타고 온 외계인 왕자  NaN                           NaN  NaN
# 27400             W의 비극  김수형                      한진흥업주식회사  NaN
# 27402             Y의 체험  이장호                       판영화사(주)  NaN
# 27403           YMCA야구단  김현석                  (주)명필름CJ ENM  NaN
#
#                  배급사         개봉일  영화유형 영화형태  국적  전국 스크린수        전국 매출액
# 0          (주)씨제이이엔엠  2014-07-30  개봉영화   장편  한국     1587  1.357484e+11  \
# ...

# %%
m.loc[(m['수입사'].isna()) & (m['국적'] != '한국')]
# Out:
#                       영화명           감독                            제작사  수입사
# 246               오! 브라더스          NaN                            NaN  NaN  \
# 460    캐리비안의 해적 : 블랙펄의 저주      고어 버빈스키  월트 디즈니 픽쳐스제리 브룩하이머 필름터치스톤 픽쳐스  NaN
# 645             나쁜 녀석들 II       마이클 베이                      콜럼비아트라이스타  NaN
# 704           신밧드:7대양의 전설  패트릭 길모어팀 존슨                            NaN  NaN
# 710               니모를 찾아서      앤드류 스탠튼                      월트디즈니코리아㈜  NaN
# ...                   ...          ...                            ...  ...
# 27345              8초의 승부    존 G. 어빌드센                        뉴라인 시네마  NaN
# 27361           A.F.T의 학살       제임스 레모                            NaN  NaN
# 27384             L.A 커넥션    레이몬드 마르티노                            NaN  NaN
# 27389              LA 리치걸        조엘 벤더                            NaN  NaN
# 27396             SAS 특공대          NaN                   랭크 필름 오가니제이션  NaN
#
# ...

# %%
m.loc[m['배급사'].isna()]
# Out:
#                     영화명           감독           제작사        수입사  배급사
# 88                   쉬리          강제규         강제규필름        NaN  NaN  \
# 246             오! 브라더스          NaN           NaN        NaN  NaN
# 629                더 게임          윤인호  (주)프라임엔터테인먼트        NaN  NaN
# 643              젠틀맨 리그      스티븐 노링턴           NaN      우성시네마  NaN
# 772    툼레이더 2 : 판도라의 상자         얀 드봉           NaN        NaN  NaN
# ...                 ...          ...           ...        ...  ...
# 27399          V2 폭파대작전  엔조 G. 카스텔라리           NaN  (주)동아수출공사  NaN
# 27400             W의 비극          김수형      한진흥업주식회사        NaN  NaN
# 27401               X게임    엠마뉴엘 그리센티           NaN    (주)한영필림  NaN
# 27402             Y의 체험          이장호       판영화사(주)        NaN  NaN
# 27403           YMCA야구단          김현석  (주)명필름CJ ENM        NaN  NaN
#
#               개봉일  영화유형 영화형태    국적  전국 스크린수        전국 매출액   전국 관객수
# 88     1999-02-13  개봉영화   장편    한국        0  0.000000e+00  5820000  \
# ...

# %%
m.loc[(m['배급사'].isna()) & (m['수입사'].isna())]
# Out:
#                     영화명    감독           제작사  수입사  배급사         개봉일  영화유형 영화형태
# 88                   쉬리   강제규         강제규필름  NaN  NaN  1999-02-13  개봉영화   장편  \
# 246             오! 브라더스   NaN           NaN  NaN  NaN  2003-09-05  개봉영화   장편
# 629                더 게임   윤인호  (주)프라임엔터테인먼트  NaN  NaN  2008-01-30  개봉영화   장편
# 772    툼레이더 2 : 판도라의 상자  얀 드봉           NaN  NaN  NaN  2003-08-01  개봉영화   장편
# 1058               해피엔드   정지우        (주)명필름  NaN  NaN  1999-12-11  개봉영화   장편
# ...                 ...   ...           ...  ...  ...         ...   ...  ...
# 27396           SAS 특공대   NaN  랭크 필름 오가니제이션  NaN  NaN  1983-08-11  개봉영화   장편
# 27398  UFO를 타고 온 외계인 왕자   NaN           NaN  NaN  NaN  1984-01-01  개봉영화   장편
# 27400             W의 비극   김수형      한진흥업주식회사  NaN  NaN  1985-06-09  개봉영화   장편
# 27402             Y의 체험   이장호       판영화사(주)  NaN  NaN  1987-10-03  개봉영화   장편
# 27403           YMCA야구단   김현석  (주)명필름CJ ENM  NaN  NaN  2002-10-02  개봉영화   장편
#
# ...

# %%
m.loc[m['개봉일'].isna()]
# Out:
#                             영화명                      감독              제작사  수입사
# 9030   순간 그리고 순간 : 디지털 삼인삼색2006  펜엑 라타나루앙에릭 쿠다레잔 오미르바예프  (재)전주국제영화제조직위원회  NaN  \
# 20380                        귀향                  이영우김효천          명보영화(주)  NaN
# 20964                        단짝                      최훈          대양필름(주)  NaN
# 21157                       도망자                     NaN              NaN  NaN
# 21691                릴로 & 스티치 2          마이클 라배시토니 레온디스              NaN  NaN
# 22203                      밀월여행                     김응천            영상의 샘  NaN
# 23029                      삶의 색              패트리시아 플라트너              NaN  NaN
# 23209                 세남자와 아기 2                     NaN              NaN  NaN
# 23796                 아기코끼리 무용담                  월트 디즈니              NaN   국제
# 23875                        아멘                코스타 가브라스              NaN  NaN
# 24230                       에너미                   톰 키니몬              NaN  NaN
# ...

# %%
for i in m['개봉일']:
    print(i)
# Out:
# 2014-07-30
# 2019-01-23
# 2017-12-20
# 2014-12-17
# 2019-04-24
# 2019-11-21
# 2009-12-17
# 2015-08-05
# 2006-07-27
# 2012-07-25
# 2013-01-23
# 2015-07-22
# 2022-05-18
# 2019-05-23
# 2012-09-13
# 2005-12-29
# 2018-08-01
# 2017-08-02
# 2004-02-05
# 2016-07-20
# 2009-07-22
# 2013-12-18
# 2018-04-25
# 2003-12-24
# 2022-12-14
# 2015-04-23
# 2019-05-30
# 2014-01-16
# 2014-11-06
# 2018-10-31
# 2016-02-03
# 2019-07-31
# 2013-09-11
# 2013-04-25
# 2013-08-01
# 2016-04-27
# 2014-01-22
# 2014-08-06
# 2009-07-29
# 2007-08-01
# 2019-12-19
# 2008-12-03
# 2022-06-22
# 2019-07-02
# 2005-08-04
# 2017-01-18
# 2011-06-29
# 2015-12-16
# 2011-12-15
# 2021-12-15
# 2009-06-24
# 2016-09-07
# 2011-08-10
# 2007-06-28
# 2011-05-04
# 2007-07-25
# 2022-07-27
# 2017-07-05
# 2017-12-27
# 2013-01-30
# 2016-12-21
# 2016-08-10
# 2012-04-26
# 2015-11-19
# 2016-07-27
# 2022-09-07
# 2016-10-13
# 2013-06-05
# 2016-05-12
# 2017-10-03
# 2006-09-28
# 2008-07-17
# 2012-10-31
# 2006-12-14
# 2017-07-26
# 2018-07-25
# ...

# %%
m = m.dropna(subset=['개봉일'])

m
# Out:
#               영화명           감독                           제작사
# 0              명량          김한민                     (주)빅스톤픽쳐스  \
# 1            극한직업          이병헌  (주)어바웃잇영화사 해그림 주식회사(주)씨제이이엔엠
# 2       신과함께-죄와 벌          김용화         리얼라이즈픽쳐스(주)(주)덱스터스튜디오
# 3            국제시장          윤제균            (주)제이케이필름(주)씨제이이엔엠
# 4      어벤져스: 엔드게임   안소니 루소조 루소                           NaN
# ...           ...          ...                           ...
# 27399    V2 폭파대작전  엔조 G. 카스텔라리                           NaN
# 27400       W의 비극          김수형                      한진흥업주식회사
# 27401         X게임    엠마뉴엘 그리센티                           NaN
# 27402       Y의 체험          이장호                       판영화사(주)
# 27403     YMCA야구단          김현석                  (주)명필름CJ ENM
#
#                       수입사                 배급사         개봉일  영화유형 영화형태    국적
# 0                     NaN           (주)씨제이이엔엠  2014-07-30  개봉영화   장편    한국  \
# 1                     NaN           (주)씨제이이엔엠  2019-01-23  개봉영화   장편    한국
# ...

# %%
m.loc[m['영화형태'].isna()]
# Out:
#                   영화명               감독
# 10648            S 중독         카모가와 테츠로  \
# 21103          더티 화이터          제임스 파르고
# 21312            드래곤볼              NaN
# 22670          블레어 윗치  에두아르드 산체스다니엘 미릭
# 23218         세번째 희생자           자크 드레이
# 23459           스캐너스2         크리스찬 두가이
# 23667            신칠용주              진준량
# 24284        에어포오드 75           잭 스마이트
# 24494           영구 람보              김주희
# 24779  우리는 그들을 잊으려 했다              NaN
# 24782     우리는그들을잊으려한다            다코 베직
# 24835            원+씩스              NaN
# 26233              탈출               왕정
# 26629             풋사랑              정진우
# 26756           핑크 팬더        블레이크 에드워즈
# 27132             후계자              최영철
#
#                                                 제작사          수입사          배급사
# 10648                                           NaN  (유)조이앤컨텐츠그룹  (유)조이앤컨텐츠그룹  \
# 21103                                           NaN        동아흥행㈜          NaN
# ...

# %%
m.loc[m['국적'].isna()]
# Out:
#                   영화명        감독  제작사      수입사  배급사         개봉일  영화유형 영화형태
# 246           오! 브라더스       NaN  NaN      NaN  NaN  2003-09-05  개봉영화   장편  \
# 21103          더티 화이터   제임스 파르고  NaN    동아흥행㈜  NaN  1979-01-28  개봉영화  NaN
# 21312            드래곤볼       NaN  NaN      NaN  NaN  1991-07-16  개봉영화  NaN
# 23459           스캐너스2  크리스찬 두가이  NaN      NaN  NaN  1991-06-29  개봉영화  NaN
# 23666             신촉산        서극  NaN  (주)건화상사  NaN  1983-04-23  개봉영화   단편
# 24779  우리는 그들을 잊으려 했다       NaN  NaN      NaN  NaN  1992-03-07  개봉영화  NaN
# 24782     우리는그들을잊으려한다     다코 베직  NaN      NaN  NaN  1992-03-27  개봉영화  NaN
# 26010       캠퍼스 연애 소동   로버트 케일러  NaN      NaN  NaN  1991-08-10  개봉영화   장편
# 26753          필사의 탈출   러스 메이버리  NaN  연방영화(주)  NaN  1976-03-20  개봉영화   장편
#
#         국적  전국 스크린수  전국 매출액   전국 관객수  서울 매출액  서울 관객수      장르         등급  영화구분
# 246    NaN        0     0.0  3148748     0.0  952010     코미디     15세관람가  일반영화
# ...

# %%
m.loc[m['전국 매출액'].isna()]
# Out:
#                 영화명           감독           제작사          수입사            배급사
# 110          살인의 추억          봉준호       (주)싸이더스          NaN         CJ ENM  \
# 125       동갑내기 과외하기          김경형    코리아 엔터테인먼트          NaN         CJ ENM
# 209    스캔들-조선남녀상열지사          이재용       (주)영화사봄          NaN         CJ ENM
# 276          황금 나침반      크리스 웨이츠       뉴라인 시네마  (주)태원엔터테인먼트  롯데쇼핑㈜롯데엔터테인먼트
# 306             황산벌          이준익       (주)씨네월드          NaN        (주)씨네월드
# ...             ...          ...           ...          ...            ...
# 27353        9월의 찻집          고영남         세기상사㈜          NaN            NaN
# 27391            O녀          변장호         동아흥행㈜          NaN            NaN
# 27393     O양의 아파트 2          변장호       연방영화(주)          NaN            NaN
# 27399      V2 폭파대작전  엔조 G. 카스텔라리           NaN    (주)동아수출공사            NaN
# 27403       YMCA야구단          김현석  (주)명필름CJ ENM          NaN            NaN
#
# ...

# %%
m.loc[m['서울 매출액'].isna()]
# Out:
#                 영화명           감독           제작사          수입사            배급사
# 110          살인의 추억          봉준호       (주)싸이더스          NaN         CJ ENM  \
# 125       동갑내기 과외하기          김경형    코리아 엔터테인먼트          NaN         CJ ENM
# 209    스캔들-조선남녀상열지사          이재용       (주)영화사봄          NaN         CJ ENM
# 276          황금 나침반      크리스 웨이츠       뉴라인 시네마  (주)태원엔터테인먼트  롯데쇼핑㈜롯데엔터테인먼트
# 306             황산벌          이준익       (주)씨네월드          NaN        (주)씨네월드
# ...             ...          ...           ...          ...            ...
# 27353        9월의 찻집          고영남         세기상사㈜          NaN            NaN
# 27391            O녀          변장호         동아흥행㈜          NaN            NaN
# 27393     O양의 아파트 2          변장호       연방영화(주)          NaN            NaN
# 27399      V2 폭파대작전  엔조 G. 카스텔라리           NaN    (주)동아수출공사            NaN
# 27403       YMCA야구단          김현석  (주)명필름CJ ENM          NaN            NaN
#
# ...

# %%
m.loc[m['장르'].isna()]
# Out:
#                    영화명        감독            제작사  수입사            배급사
# 9666         섹스 인 더 게임       신성진         선셋 시네마  NaN         선셋 시네마  \
# 9707   형님 아내4(우주공주 춘향)        이돌          이돌영화사  NaN          이돌영화사
# 9721       요정 미인관 무삭제판       에로핑  (주)씨맥스커뮤니케이션즈  NaN  (주)씨맥스커뮤니케이션즈
# 9756          처음엔 다 그래       박선재         컨버전스티비  NaN         컨버전스티비
# 9773            발칙한 동거       오재학       노바엔터테인먼트  NaN       노바엔터테인먼트
# ...                ...       ...            ...  ...            ...
# 27188              흑수도       하몽화             안양  NaN            NaN
# 27193            흑야비룡도        김묵           신창필름  NaN            NaN
# 27199               흑조       이상언           유림흥업  NaN            NaN
# 27226               0시       이만희           태창흥업  NaN            NaN
# 27249             10+1  우스필립 라브로            NaN  NaN            NaN
#
#               개봉일  영화유형 영화형태   국적  전국 스크린수     전국 매출액  전국 관객수    서울 매출액
# 9666   2018-03-28  개봉영화   장편   한국       20  1021000.0     184  664000.0  \
# ...

# %%
m.loc[m['등급'].isna()]
# Out:
#                영화명           감독                     제작사         수입사
# 914            뉴월드       테렌스 맬릭                 뉴라인 시네마         NaN  \
# 1040         판타스틱4        팀 스토리  마블 엔터테인먼트이십세기폭스필름코퍼레이션         NaN
# 1066   80일간의 세계 일주      프랑코 코라시                  (주)쇼박스  월트 디즈니 픽쳐스
# 9334        빛나는 거짓           채기                  빛나는영화사         NaN
# 20042    가시를 삼킨 장미          정진우                 (주)우진필림         NaN
# ...            ...          ...                     ...         ...
# 27323  500만 달러의 모험          NaN                     NaN         NaN
# 27330      7인의 독수리     더글러스 힉콕스            이십세기폭스코리아(주)     (주)삼영필림
# 27334       7인의 신부       스탠리 도넌             메트로-골드윈-마이어   (주)동아수출공사
# 27397      SOS 대폭발        제임스 힐             워너 브러더스 픽쳐스          국제
# 27399     V2 폭파대작전  엔조 G. 카스텔라리                     NaN   (주)동아수출공사
#
#                 배급사         개봉일  영화유형 영화형태    국적  전국 스크린수  전국 매출액  전국 관객수
# 914         쇼이스트(주)  2005-11-25  개봉영화   장편    미국        0     0.0  925154  \
# ...

# %%
m[['전국 스크린수', '전국 매출액', '전국 관객수', '서울 매출액', '서울 관객수']].corr()
# Out:
#           전국 스크린수    전국 매출액    전국 관객수    서울 매출액    서울 관객수
# 전국 스크린수  1.000000  0.710311  0.622803  0.701440  0.529968
# 전국 매출액   0.710311  1.000000  0.906152  0.987997  0.805052
# 전국 관객수   0.622803  0.906152  1.000000  0.897670  0.910400
# 서울 매출액   0.701440  0.987997  0.897670  1.000000  0.816120
# 서울 관객수   0.529968  0.805052  0.910400  0.816120  1.000000

# %%
m.등급.unique()
# Out:
# array(['15세이상관람가', '12세이상관람가', '전체관람가', '12세관람가', '15세관람가', '청소년관람불가',
#        '18세관람가', '15세 미만인 자는 관람할 수 없는 등급', '12세이상관람가12세관람가',
#        '15세관람가15세이상관람가', nan, '청소년관람불가15세이상관람가', '18세관람가15세이상관람가',
#        '18세관람가청소년관람불가', '12세이상관람가전체관람가', '12세이상관람가15세이상관람가',
#        '15세이상관람가전체관람가', '연소자관람불가청소년관람불가', '제한상영가', '15세관람가12세이상관람가',
#        '고등학생이상관람가', '연소자관람불가', '모든 관람객이 관람할 수 있는 등급', '중학생이상관람가',
#        '연소자관람가', '국민학생관람불가', '미성년자관람불가', '연소자관람불가15세이상관람가',
#        '18세 미만인 자는 관람할 수 없는 등급', '12세이상관람가연소자관람가', '연소자관람가15세이상관람가',
#        '15세이상관람가중학생이상관람가', '12세 미만인 자는 관람할 수 없는 등급',
#        '15세 미만인 자는 관람할 수 없는 등급 15세이상관람가', '기타', '연소자관람가전체관람가',
#        '15세이상관람가18세 미만인 자는 관람할 수 없는 등급', '미정', '고등학생이상관람가15세이상관람가',
#        '15세이상관람가미성년자관람불가', '미성년자관람가', '국민학생관람불가15세이상관람가',
#        '12세이상관람가중학생이상관람가', '고등학생이상관람가청소년관람불가', '12세이상관람가국민학생관람불가15세이상관람가',
#        '12세이상관람가국민학생관람불가', '12세이상관람가연소자관람가전체관람가', '청소년관람불가12세관람가',
# ...

# %%
# 데이터 불러오기
fig = px.pie(m, values='전국 관객수', names='등급')

fig.update_layout(
    title='등급별 관람수',
    title_x = 0.5,
    title_y = 0.9,
    title_xanchor = "center",
    title_yanchor = "middle",
    title_font_size = 25,
    title_font_family = "Times")

fig.show()

# %%
m.loc[m['GRAD_NM'] == '15세관람가', 'GRAD_NM'] = '15세이상관람가'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\DACON-AI\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\user\anaconda3\envs\DACON-AI\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\user\anaconda3\envs\DACON-AI\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GRAD_NM'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# 데이터 불러오기
fig = px.pie(m, values='VIEWNG_NMPR_CO', names='GRAD_NM')

fig.update_layout(
    title='등급별 관람인원',
    title_x = 0.5,
    title_y = 0.9,
    title_xanchor = "center",
    title_yanchor = "middle",
    title_font_size = 25,
    title_font_family = "Times")

fig.show()
