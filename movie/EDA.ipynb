# %%
import pandas as pd
import plotly.express as px

# %%
m20 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_2020.csv')
m2101 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202101.csv')
m2102 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202102.csv')
m2103 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202103.csv')
m2104 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202104.csv')
m2105 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202105.csv')
m2106 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202106.csv')
m2107 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202107.csv')
m2108 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202108.csv')
m2109 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202109.csv')
m2110 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202110.csv')
m2111 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202111.csv')
m2112 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202112.csv')
m2201 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202201.csv')
m2202 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202202.csv')
m2203 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202203.csv')
m2204 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202204.csv')
m2205 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202205.csv')
m2206 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202206.csv')
m2207 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202207.csv')
m2208 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202208.csv')
m2209 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202209.csv')
m2210 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202210.csv')
m2211 = pd.read_csv('src/KOBIS 박스오피스 영화정보/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_202211.csv')

'''
순서 컬럼영문명            컬럼한글명    데이터타입 길이 PK여부 NOT NULL여부
1    NO                   번호          DECIMAL	 30,0     N            N
2    MOVIE_NM             영화명        VARCHAR	  200     N            N
3    DRCTR_NM             감독명        VARCHAR	  200     N            N
4    MAKR_NM              제작사명      VARCHAR	  200     N            N
5    INCME_CMPNY_NM       수입회사명    VARCHAR	  200     N            N
6    DISTB_CMPNY_NM       유통회사명    VARCHAR	  200     N            N
7    OPN_DE               개방일자      VARCHAR	    8     N            N
8    MOVIE_TY_NM          영화유형명    VARCHAR	  200     N            N
9    MOVIE_STLE_NM        영화형태명    VARCHAR	  200     N            N
10   NLTY_NM              국적명        VARCHAR	  200     N            N
11   TOT_SCRN_CO          총스크린수     DECIMAL  28,5    N            N
12   SALES_PRICE          매출금액       DECIMAL  28,5    N            N
13   VIEWNG_NMPR_CO       관람인원수     DECIMAL  28,5    N            N
14   SEOUL_SALES_PRICE	  서울매출금액   DECIMAL  28,5    N            N
15   SEOUL_VIEWNG_NMPR_CO 서울관람인원수 DECIMAL  28,5    N            N
16   GENRE_NM	          장르명        VARCHAR   200     N            N
17   GRAD_NM	          등급명        VARCHAR	  200     N            N
18   MOVIE_SDIV_NM        영화구분명     VARCHAR   30     N            N
'''
# Out:
# '\n순서 컬럼영문명            컬럼한글명    데이터타입 길이 PK여부 NOT NULL여부\n1    NO                   번호          DECIMAL\t 30,0     N            N\n2    MOVIE_NM             영화명        VARCHAR\t  200     N            N\n3    DRCTR_NM             감독명        VARCHAR\t  200     N            N\n4    MAKR_NM              제작사명      VARCHAR\t  200     N            N\n5    INCME_CMPNY_NM       수입회사명    VARCHAR\t  200     N            N\n6    DISTB_CMPNY_NM       유통회사명    VARCHAR\t  200     N            N\n7    OPN_DE               개방일자      VARCHAR\t    8     N            N\n8    MOVIE_TY_NM          영화유형명    VARCHAR\t  200     N            N\n9    MOVIE_STLE_NM        영화형태명    VARCHAR\t  200     N            N\n10   NLTY_NM              국적명        VARCHAR\t  200     N            N\n11   TOT_SCRN_CO          총스크린수     DECIMAL  28,5    N            N\n12   SALES_PRICE          매출금액       DECIMAL  28,5    N            N\n13   VIEWNG_NMPR_CO       관람인원수     DECIMAL  28,5    N            N\n14   SEOUL_SALES_PRIC
# ...

# %%
m_list = [m20, m2101, m2102, m2103, m2104, m2105, m2106, m2107, m2108, m2109, m2110, 
           m2111, m2112, m2201, m2202, m2203, m2204, m2205, m2206, m2207, m2208, m2209, m2210, m2211]

m = pd.concat(m_list, ignore_index=True)

m
# Out:
#          NO        MOVIE_NM  DRCTR_NM      MAKR_NM INCME_CMPNY_NM
# 0       1.0         남산의 부장들       우민호  (주)하이브미디어코프            NaN  \
# 1       2.0     다만 악에서 구하소서       홍원찬  (주)하이브미디어코프            NaN
# 2       3.0              반도       연상호   (주)영화사레드피터            NaN
# 3       4.0             히트맨       최원섭   베리굿스튜디오(주)            NaN
# 4       5.0              테넷  크리스토퍼 놀란          NaN  워너브러더스 코리아(주)
# ...     ...             ...       ...          ...            ...
# 7548  250.0       흠뻑적신 음란시술       NaN          NaN            NaN
# 7549  251.0   히트맨: 코드네임 버튜소       NaN          NaN       (주)누리픽쳐스
# 7550  252.0     3대 1은 처음이지?       김혜연     영화사 레드카펫            NaN
# 7551  253.0        MZ세대 쓰리섬       김소리  주식회사 루믹스미디어            NaN
# 7552  254.0  XX 니들은 하지마라 결혼       전성기  주식회사 바나나픽쳐스            NaN
#
#            DISTB_CMPNY_NM    OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM
# 0                  (주)쇼박스  20200122        개봉영화            장편      한국  \
# ...

# %%
m = m.drop(['NO'], axis=1)

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7553 entries, 0 to 7552
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MOVIE_NM              7438 non-null   object
#  1   DRCTR_NM              6269 non-null   object
#  2   MAKR_NM               3151 non-null   object
#  3   INCME_CMPNY_NM        2722 non-null   object
#  4   DISTB_CMPNY_NM        7437 non-null   object
#  5   OPN_DE                7437 non-null   object
#  6   MOVIE_TY_NM           7438 non-null   object
#  7   MOVIE_STLE_NM         7438 non-null   object
#  8   NLTY_NM               7438 non-null   object
#  9   TOT_SCRN_CO           7190 non-null   float64
#  10  SALES_PRICE           3182 non-null   float64
#  11  VIEWNG_NMPR_CO        6277 non-null   float64
#  12  SEOUL_SALES_PRICE     5012 non-null   float64
#  13  SEOUL_VIEWNG_NMPR_CO  6497 non-null   float64
#  14  GENRE_NM              7434 non-null   object
# ...

# %%
m.loc[m['DRCTR_NM'].isna()]
# Out:
#                         MOVIE_NM DRCTR_NM        MAKR_NM INCME_CMPNY_NM
# 43                     프리즌 이스케이프      NaN            NaN      주식회사 풍경소리  \
# 64     그대, 고맙소 : 김호중 생애 첫 팬미팅 무비      NaN  씨제이포디플렉스 주식회사            NaN
# 82                         더 플랫폼      NaN            NaN        주식회사 더쿱
# 107                           그집      NaN            NaN      (유)조이앤시네마
# 117   극장판 바다 탐험대 옥토넛 : 대산호초 보호작전      NaN            NaN     (주)얼리버드픽쳐스
# ...                          ...      ...            ...            ...
# 7525           육욕 음부 들이미는 직장 여상사      NaN            NaN            NaN
# 7534               저의 아내는 불량품입니다      NaN            NaN            NaN
# 7540             질펀한 마사지 : 물 터졌어      NaN            NaN            NaN
# 7548                   흠뻑적신 음란시술      NaN            NaN            NaN
# 7549               히트맨: 코드네임 버튜소      NaN            NaN       (주)누리픽쳐스
#
#                 DISTB_CMPNY_NM    OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM
# ...

# %%
m.loc[m['MAKR_NM'].isna()]
# Out:
#                 MOVIE_NM  DRCTR_NM MAKR_NM            INCME_CMPNY_NM
# 4                     테넷  크리스토퍼 놀란     NaN             워너브러더스 코리아(주)  \
# 9                 닥터 두리틀    스티븐 개건     NaN       유니버설픽쳐스인터내셔널 코리아(유)
# 18                  1917     샘 멘데스     NaN                 (주)씨제이이엔엠
# 19                작은 아씨들    그레타 거윅     NaN  소니픽쳐스엔터테인먼트코리아주식회사극장배급지점
# 20                  미드웨이  롤랜드 에머리히     NaN                  (주)누리픽쳐스
# ...                  ...       ...     ...                       ...
# 7542  트레이너에게 젖어버린 일본 유부녀     히무 롯쿠     NaN                       NaN
# 7543      풍만한 며느리:뭐든지 OK     사쿠라비토     NaN                       NaN
# 7546    핫바디 새엄마:엉덩이가 죽여줘     사쿠라비토     NaN                       NaN
# 7548           흠뻑적신 음란시술       NaN     NaN                       NaN
# 7549       히트맨: 코드네임 버튜소       NaN     NaN                  (주)누리픽쳐스
#
#                 DISTB_CMPNY_NM    OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM
# ...

# %%
m.loc[m['INCME_CMPNY_NM'].isna() & m['NLTY_NM'] != '한국']
# Out:
#                   MOVIE_NM DRCTR_NM                            MAKR_NM
# 0                  남산의 부장들      우민호                        (주)하이브미디어코프  \
# 1              다만 악에서 구하소서      홍원찬                        (주)하이브미디어코프
# 2                       반도      연상호                         (주)영화사레드피터
# 3                      히트맨      최원섭                         베리굿스튜디오(주)
# 5                      백두산  이해준,김병서  주식회사 덱스터 픽쳐스,(주)퍼펙트스톰필름,(주)씨제이이엔엠
# ...                    ...      ...                                ...
# 7547  흑형의 맛 : 울부짖는 여자들 무삭제      조필구                           (주)영화사가을
# 7548             흠뻑적신 음란시술      NaN                                NaN
# 7550           3대 1은 처음이지?      김혜연                           영화사 레드카펫
# 7551              MZ세대 쓰리섬      김소리                        주식회사 루믹스미디어
# 7552        XX 니들은 하지마라 결혼      전성기                        주식회사 바나나픽쳐스
#
#      INCME_CMPNY_NM        DISTB_CMPNY_NM    OPN_DE MOVIE_TY_NM MOVIE_STLE_NM
# ...

# %%
# 총스크린수, 매출금액, 관람인원수, 서울매출금액, 서울관람인원수
m[['TOT_SCRN_CO', 'SALES_PRICE', 'VIEWNG_NMPR_CO', 'SEOUL_SALES_PRICE', 'SEOUL_VIEWNG_NMPR_CO']].corr()
# Out:
#                       TOT_SCRN_CO  SALES_PRICE  VIEWNG_NMPR_CO
# TOT_SCRN_CO              1.000000     0.564071        0.526387  \
# SALES_PRICE              0.564071     1.000000        0.999089
# VIEWNG_NMPR_CO           0.526387     0.999089        1.000000
# SEOUL_SALES_PRICE        0.574333     0.986052        0.983074
# SEOUL_VIEWNG_NMPR_CO     0.540410     0.988247        0.987644
#
#                       SEOUL_SALES_PRICE  SEOUL_VIEWNG_NMPR_CO
# TOT_SCRN_CO                    0.574333              0.540410
# SALES_PRICE                    0.986052              0.988247
# VIEWNG_NMPR_CO                 0.983074              0.987644
# SEOUL_SALES_PRICE              1.000000              0.998207
# SEOUL_VIEWNG_NMPR_CO           0.998207              1.000000

# %%
# 데이터 불러오기
fig = px.pie(m, values='VIEWNG_NMPR_CO', names='GRAD_NM')

fig.update_layout(
    title='등급별 관람인원',
    title_x = 0.5,
    title_y = 0.9,
    title_xanchor = "center",
    title_yanchor = "middle",
    title_font_size = 25,
    title_font_family = "Times")

fig.show()

# %%
m.loc[m['GRAD_NM'] == '15세관람가'] = '15세이상관람가'

# %%
# 데이터 불러오기
fig = px.pie(m, values='VIEWNG_NMPR_CO', names='GRAD_NM')

fig.update_layout(
    title='등급별 관람인원',
    title_x = 0.5,
    title_y = 0.9,
    title_xanchor = "center",
    title_yanchor = "middle",
    title_font_size = 25,
    title_font_family = "Times")

fig.show()
